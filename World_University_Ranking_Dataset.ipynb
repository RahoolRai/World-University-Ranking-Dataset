# %% [markdown]
# # 🏫 World University Ranking Dataset & Task~1 Digipex AI Internship
# --->
# This notebook focuses on analyzing global university rankings to uncover patterns and insights that can help students, institutions, and policymakers make data-driven decisions.University rankings play a vital role in evaluating educational performance and global reputation.

# %% [markdown]
# # 🎯 Goal
# ---> Perform Exploratory Data Analysis (EDA) and derive valuable insights from global university ranking data.
#
# # 💡 Why It Matters?
# ---> Rankings influence student decisions, research funding, institutional strategy, and global partnerships. Understanding what drives rankings is crucial.
#
# # ❓ Problem Statement
# ---> I’m supporting the Education Insights Team to:
#
# ✅ Explore how universities are ranked across countries and years
# ✅ Identify factors that impact global university rankings
# ✅ Provide actionable insights for educational improvement
#
# # 📂 Dataset Used
# Sourced from Kaggle – World University Rankings
#
# # 🧮 Dataset Highlights:
# 🏫 01. Institution Info : University name, Location, World Rank
# 📅 02. Timeline : Rankings across multiple years
# 📊 03. Performance Metrics : Teaching, International outlook, Research, Citations, Industry Income
# 🌍 04. Global Perspective : Region-wise performance, country-level insights
#
# # 🔧 Steps to Follow
# 📥 01. Load & Understand the Data
# 🧹 02. Clean Missing & Inconsistent Entries
# 📊 03. Visualize Trends, Patterns & Comparisons
# 📈 04. Derive Actionable Business Insights
# 📌 05. Recommend Strategies for Educational Growth

# %% [markdown]
# # 🔹 Step-1 : Import all libraries which are required for dataset.

# %%
# Import the all requires libraries for cleaning or preprocessing and Visualizations of World University Ranking Dataset.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 🔹Step-2 : Load & Explore Dataset of World University Ranking

# %%
# Load the dataset of World University Ranking Dataset
df = pd.read_csv("World_University_Ranking_Dataset.csv")
df
# Out:
#                  University_Name      Country  World_Rank  Research_Score  \
# 0        University of Germany 1          USA           1           89.39
# 1          University of India 2        India           2           40.22
# 2    University of South Korea 3       Canada           3           84.81
# 3      University of Australia 4        India           4           31.17
# 4          University of China 5       France           5           91.69
# ..                           ...          ...         ...             ...
# 495     University of Canada 496  South Korea         496           84.16
# 496     University of Canada 497        Japan         497           80.71
# 497        University of USA 498        Japan         498           32.56
# 498        University of USA 499        Japan         499           55.97
# 499      University of China 500           UK         500           93.14
#
#      Teaching_Score  Citations  Student_Staff_Ratio  \
# ...

# %% [markdown]
# # 🔹Step-3 :🧹 Data Cleaning or Preprocessing of the World University Dataset
#  The dataset was carefully cleaned by identifying and handling missing values in key numerical columns such as 'Citations', 'Teaching_Score', and 'International_Students_Percent' using mean imputation to ensure consistency and reliability for analysis.

# %%
# Show the first five rows of World University Ranking Dataset
df.head()
# Out:
#                University_Name Country  World_Rank  Research_Score  \
# 0      University of Germany 1     USA           1           89.39
# 1        University of India 2   India           2           40.22
# 2  University of South Korea 3  Canada           3           84.81
# 3    University of Australia 4   India           4           31.17
# 4        University of China 5  France           5           91.69
#
#    Teaching_Score  Citations  Student_Staff_Ratio  \
# 0           90.74    17801.0                 18.2
# 1           36.62    73706.0                  9.8
# 2           82.06    92057.0                 16.4
# 3           78.04    82354.0                 26.2
# 4           89.74    39867.0                 11.4
#
#    International_Students_Percent
# 0                            47.9
# 1                             NaN
# 2                            47.2
# 3                            57.1
# 4                             NaN

# %%
# Show the last five rows of World University Ranking Dataset
df.tail()
# Out:
#               University_Name      Country  World_Rank  Research_Score  \
# 495  University of Canada 496  South Korea         496           84.16
# 496  University of Canada 497        Japan         497           80.71
# 497     University of USA 498        Japan         498           32.56
# 498     University of USA 499        Japan         499           55.97
# 499   University of China 500           UK         500           93.14
#
#      Teaching_Score  Citations  Student_Staff_Ratio  \
# 495           98.68    83451.0                 28.5
# 496           92.57    54605.0                 28.7
# 497           94.10    74260.0                 26.3
# 498           68.23    14604.0                 20.7
# 499           79.50    12560.0                 28.7
#
#      International_Students_Percent
# 495                            40.8
# 496                            52.1
# 497                            37.0
# 498                            46.0
# 499                            18.8

# %%
# Show the information of Column's data types and non-null counts of World University Ranking Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   University_Name                 500 non-null    object
#  1   Country                         500 non-null    object
#  2   World_Rank                      500 non-null    int64
#  3   Research_Score                  500 non-null    float64
#  4   Teaching_Score                  485 non-null    float64
#  5   Citations                       485 non-null    float64
#  6   Student_Staff_Ratio             500 non-null    float64
#  7   International_Students_Percent  485 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 31.4+ KB

# %%
# Number of unique values in each column of World University Ranking Dataset
df.nunique()
# Out:
# University_Name                   500
# Country                            10
# World_Rank                        500
# Research_Score                    487
# Teaching_Score                    469
# Citations                         485
# Student_Staff_Ratio               216
# International_Students_Percent    324
# dtype: int64

# %%
# Show the statistics information of numeric columns of World University Ranking Dataset 
df.describe()
# Out:
#        World_Rank  Research_Score  Teaching_Score     Citations  \
# count  500.000000      500.000000      485.000000    485.000000
# mean   250.500000       65.189320       65.334021  49841.362887
# std    144.481833       20.050286       20.458475  28968.856079
# min      1.000000       30.050000       30.050000   1217.000000
# 25%    125.750000       48.807500       46.720000  23641.000000
# 50%    250.500000       65.505000       65.640000  49877.000000
# 75%    375.250000       81.940000       83.840000  74751.000000
# max    500.000000      100.000000       99.970000  99854.000000
#
#        Student_Staff_Ratio  International_Students_Percent
# count           500.000000                      485.000000
# mean             17.635800                       32.744742
# std               6.801551                       15.450217
# min               5.000000                        5.100000
# 25%              12.000000                       20.100000
# ...

# %%
# Check the missing values in each column of World University Ranking Dataset
print(df.isnull().sum())
# Out:
# University_Name                    0
# Country                            0
# World_Rank                         0
# Research_Score                     0
# Teaching_Score                    15
# Citations                         15
# Student_Staff_Ratio                0
# International_Students_Percent    15
# dtype: int64

# %%
# Fill missing numerical values with the column mean 
df['Citations'].fillna(df['Citations'].mean(), inplace=True)
df['International_Students_Percent'].fillna(df['International_Students_Percent'].mean(), inplace=True)
df['Teaching_Score'].fillna(df['Teaching_Score'].mean(), inplace=True)
df
# Out:
# C:\Users\Rahool-Rai\AppData\Local\Temp\ipykernel_9136\2922785851.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Citations'].fillna(df['Citations'].mean(), inplace=True)
# C:\Users\Rahool-Rai\AppData\Local\Temp\ipykernel_9136\2922785851.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# # 🔹Step-4 : Verify all missing values are Handled and Should return 0 for all columns of World University Ranking Dataset

# %%
# Verify all missing values are Handled and Should return 0 for all columns of World University Ranking Dataset 
print(df.isnull().sum())
# Out:
# University_Name                   0
# Country                           0
# World_Rank                        0
# Research_Score                    0
# Teaching_Score                    0
# Citations                         0
# Student_Staff_Ratio               0
# International_Students_Percent    0
# dtype: int64

# %% [markdown]
# # 📊 Create the Visualizations include 7 different types of visualizations of World University Ranking Dataset which are given.

# %% [markdown]
# # 📊 Visualization Summary Of World University Ranking Dataset
# ---> A variety of visualizations including bar charts, line plots, histograms, heatmaps, pie charts, box plots, and scatter plots were used to explore and present insights from the dataset, uncovering trends in research output, international diversity, and university performance across countries.

# %% [markdown]
# # 📊 1. Bar Graph :  Top 10 Universities by Research Score
# ---> Shows the top universities globally based on research performance.
# Helps compare which countries are leading in academic research output.

# %%
# 1. Bar Graph: Top 10 Universities by Research Score
top10_research = df.nlargest(10, 'Research_Score')
sns.barplot(x='Research_Score', y='University_Name', data=top10_research, palette='viridis')
plt.title('Top 10 Universities by Research Score')
plt.xlabel('Research Score')
plt.ylabel('University Name')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Rahool-Rai\AppData\Local\Temp\ipykernel_9136\837371494.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Research_Score', y='University_Name', data=top10_research, palette='viridis')

# %% [markdown]
# # 📈 2. Line Graph : Average Research Score Over Time
# ---> Displays trends in research score across years.
# Reveals improvements or declines in research productivity.

# %%
# 2. Line Graph: World Rank vs Research Score (Top 50)
sns.lineplot(x='World_Rank', y='Research_Score', data=df.head(50), marker='o')
plt.title('World Rank vs Research Score (Top 50)')
plt.xlabel('World Rank')
plt.ylabel('Research Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 📉 3. Histogram Graph : Distribution of Teaching Scores
# ---> Shows the frequency of teaching scores across universities.
# Helps identify how many institutions offer high-quality teaching.

# %%
# 3. Histogram: Distribution of Student-Staff Ratio
sns.histplot(df['Student_Staff_Ratio'], bins=20, kde=True, color='skyblue')
plt.title('Histogram of Student-Staff Ratio')
plt.xlabel('Student-Staff Ratio')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🔥 4. Heatmap Graph : Correlation Between Ranking Factors
# ---> Visualizes relationships between metrics like research, teaching, and citations.
# Identifies which factors most influence overall university rankings.

# %%
# 4. Heatmap: Correlation Between Numeric Features
correlation = df.corr(numeric_only=True)
sns.heatmap(correlation, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of University Metrics')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🥧 5. Pie Chart : Distribution of Top Universities by Country
# ---> Displays how many top universities each country contributes.
# Highlights dominant nations in higher education.

# %%
# 5. Pie Chart: Distribution of Universities by Country (Top 5 Countries)
top_countries = df['Country'].value_counts().nlargest(5)
plt.pie(top_countries, labels=top_countries.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Top 5 Countries by University Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 📦 6. Box Plot : Spread of Citation Scores
# ---> Illustrates the distribution and outliers in citation scores.
# Shows which institutions have extremely high academic influence.

# %%
# 6. Box Plot: Research Score by Country (Top 5 Countries)
top5 = df[df['Country'].isin(df['Country'].value_counts().nlargest(5).index)]
sns.boxplot(x='Country', y='Research_Score', data=top5, palette='Set3')
plt.title('Research Score Distribution by Country')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Rahool-Rai\AppData\Local\Temp\ipykernel_9136\3973549888.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Country', y='Research_Score', data=top5, palette='Set3')

# %% [markdown]
# # ⚫ 7. Scatter Plot : Teaching vs Research Score
# ---> Shows the relationship between teaching and research quality.
# Reveals whether better teaching aligns with better research.

# %%
# 7. Scatter Plot: Citations vs Research Score
sns.scatterplot(x='Citations', y='Research_Score', data=df, hue='Country', alpha=0.7)
plt.title('Citations vs Research Score')
plt.xlabel('Citations')
plt.ylabel('Research Score')
plt.tight_layout()
plt.show()
